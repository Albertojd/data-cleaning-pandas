# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv(('attacks.csv'), encoding = 'ISO-8859-1')

# %%
df.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
interest_df = df.drop(['pdf','href formula', 'href','Location','Name', "Unnamed: 22","Unnamed: 23"], axis = 1)
interest_df
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area     Activity Sex   Age  \
# 0           California     Paddling    F   57
# 1              Georgia     Standing    F   11
# 2               Hawaii      Surfing    M   48
# ...

# %%
interest_df.duplicated().sum()
# Out:
# 19411

# %%
df_clean = interest_df.drop_duplicates()

# %%
df_clean.duplicated().sum()
# Out:
# 0

# %%
df_clean.head(10)
# Out:
#     Case Number         Date    Year        Type    Country             Area  \
# 0    2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1    2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2    2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3    2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4    2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
# 5  2018.06.03.b  03-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 6  2018.06.03.a  03-Jun-2018  2018.0  Unprovoked     BRAZIL       Pernambuco
# 7    2018.05.27  27-May-2018  2018.0  Unprovoked        USA          Florida
# 8  2018.05.26.b  26-May-2018  2018.0  Unprovoked        USA          Florida
# 9  2018.05.26.a  26-May-2018  2018.0  Unprovoked        USA          Florida
#
#        Activity Sex   Age                                             Injury  \
# ...

# %%
df_clean.isnull().sum()
# Out:
# Case Number                  2
# Date                        10
# Year                        12
# Type                        14
# Country                     60
# Area                       465
# Activity                   554
# Sex                        575
# Age                       2841
# Injury                      38
# Fatal (Y/N)                549
# Time                      3364
# Species                   2848
# Investigator or Source      27
# Case Number.1               10
# Case Number.2               10
# original order               3
# dtype: int64

# %%
df_clean.isnull().sum()
# Out:
# Case Number                  2
# Date                        10
# Year                        12
# Type                        14
# Country                     60
# Area                       465
# Activity                   554
# Sex                        575
# Age                       2841
# Injury                      38
# Fatal (Y/N)                549
# Time                      3364
# Species                   2848
# Investigator or Source      27
# Case Number.1               10
# Case Number.2               10
# original order               3
# dtype: int64

# %%
df_clean[['Year']] = df_clean[['Year']].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-172-a9e71bca707f> in <module>
# ----> 1 df_clean[['Year']] = df_clean[['Year']].astype(int)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ...

# %%
df_clean
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 6307            0          NaN     NaN         NaN        NaN
# 6308            0          NaN     NaN         NaN        NaN
# 6309            0          NaN     NaN         NaN        NaN
# 8702          NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area     Activity Sex   Age  \
# 0           California     Paddling    F   57
# 1              Georgia     Standing    F   11
# 2               Hawaii      Surfing    M   48
# ...

# %%
interest_data = df_clean[['Year','Date', 'Activity']]

interest_data
# Out:
#          Year         Date     Activity
# 0      2018.0  25-Jun-2018     Paddling
# 1      2018.0  18-Jun-2018     Standing
# 2      2018.0  09-Jun-2018      Surfing
# 3      2018.0  08-Jun-2018      Surfing
# 4      2018.0  04-Jun-2018  Free diving
# ...       ...          ...          ...
# 6307      NaN          NaN          NaN
# 6308      NaN          NaN          NaN
# 6309      NaN          NaN          NaN
# 8702      NaN          NaN          NaN
# 25722     NaN          NaN          NaN
#
# [6312 rows x 3 columns]

# %%
df_clean.count(axis = 0)
# Out:
# Case Number               6310
# Date                      6302
# Year                      6300
# Type                      6298
# Country                   6252
# Area                      5847
# Activity                  5758
# Sex                       5737
# Age                       3471
# Injury                    6274
# Fatal (Y/N)               5763
# Time                      2948
# Species                   3464
# Investigator or Source    6285
# Case Number.1             6302
# Case Number.2             6302
# original order            6309
# dtype: int64
